# %% [markdown]
# File I need to preprocess my test data. Before pre processing training data I split the original CSV and train and test to prevent data leakage from training to test

# %% [markdown]
# # IMPORT LIBRARIES

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import skew


import ast
import os
import glob
import json
import time
from collections import Counter
import math


from sklearn.dummy import DummyClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler

from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MultiLabelBinarizer

from skrub import TableReport, Cleaner
from skore import EstimatorReport, CrossValidationReport, train_test_split


from utils import backup_dataframe, load_latest_backup, printmd

# %% [markdown]
# # DATA PREP

# %%
df = pd.read_csv("dataset/test_raw.csv")

# %%
TableReport(df)
# Out:
# Processing column  33 / 33
# <TableReport: use .open() to display>

# %%
for i in df.columns:
    print("***********************")
    print((((df[f"{i}"] == "\\N").value_counts()) * 100) / df.shape[0])
    print("***********************")
